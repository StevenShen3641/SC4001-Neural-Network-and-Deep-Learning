# %% [markdown]
# # Question B1 (15 marks)
#
# Real world datasets often have a mix of numeric and categorical features – this dataset is one example. To build models on such data, categorical features have to be encoded or embedded.
#
# PyTorch Tabular is a library that makes it very convenient to build neural networks for tabular data. It is built on top of PyTorch Lightning, which abstracts away boilerplate model training code and makes it easy to integrate other tools, e.g. TensorBoard for experiment tracking.
#
# For questions B1 and B2, the following features should be used:
# - **Numeric / Continuous** features: dist_to_nearest_stn, dist_to_dhoby, degree_centrality, eigenvector_centrality, remaining_lease_years, floor_area_sqm
# - **Categorical** features: month, town, flat_model_type, storey_range

# %% [markdown]
# ---

# %%
# !pip install pytorch_tabular[extra]
# Out:
# Requirement already satisfied: pytorch_tabular[extra] in d:\program files\python310\lib\site-packages (1.1.0)
# Requirement already satisfied: numpy>1.20.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (1.24.3)
# Requirement already satisfied: protobuf<4.26.0,>=3.20.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (4.23.4)
# Requirement already satisfied: pytorch-lightning<2.2.0,>=2.0.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (2.1.4)
# Requirement already satisfied: PyYAML<6.1.0,>=5.4 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (6.0)
# Requirement already satisfied: pandas>=1.1.5 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (2.0.1)
# Requirement already satisfied: rich>=11.0.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (13.7.1)
# Requirement already satisfied: einops<0.8.0,>=0.6.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (0.7.0)
# Requirement already satisfied: torch>=1.11.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (2.1.2+cu121)
# Requirement already satisfied: pytorch-tabnet==4.1 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (4.1.0)
# Requirement already satisfied: omegaconf>=2.3.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (2.3.0)
# Requirement already satisfied: tensorboard!=2.5.0,>2.2.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (2.13.0)
# Requirement already satisfied: matplotlib>3.1 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (3.7.1)
# Requirement already satisfied: torchmetrics<1.3.0,>=0.10.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (1.2.1)
# Requirement already satisfied: scikit-learn>=1.3.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (1.4.1.post1)
# Requirement already satisfied: ipywidgets in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (8.1.2)
# Requirement already satisfied: kaleido<0.3.0,>=0.2.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (0.2.1)
# Requirement already satisfied: captum<0.8.0,>=0.5.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (0.7.0)
# Requirement already satisfied: plotly<5.19.0,>=5.13.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (5.18.0)
# Requirement already satisfied: wandb<0.17.0,>=0.15.0 in d:\program files\python310\lib\site-packages (from pytorch_tabular[extra]) (0.16.4)
# Requirement already satisfied: tqdm>=4.36 in d:\program files\python310\lib\site-packages (from pytorch-tabnet==4.1->pytorch_tabular[extra]) (4.65.0)
# Requirement already satisfied: scipy>1.4 in d:\program files\python310\lib\site-packages (from pytorch-tabnet==4.1->pytorch_tabular[extra]) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\program files\python310\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\program files\python310\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\program files\python310\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in d:\program files\python310\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\program files\python310\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (4.39.4)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\program files\python310\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\program files\python310\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\program files\python310\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (9.5.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in d:\program files\python310\lib\site-packages (from omegaconf>=2.3.0->pytorch_tabular[extra]) (4.9.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\program files\python310\lib\site-packages (from pandas>=1.1.5->pytorch_tabular[extra]) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in d:\program files\python310\lib\site-packages (from pandas>=1.1.5->pytorch_tabular[extra]) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in d:\program files\python310\lib\site-packages (from plotly<5.19.0,>=5.13.0->pytorch_tabular[extra]) (8.2.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\program files\python310\lib\site-packages (from pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (4.4.0)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in d:\program files\python310\lib\site-packages (from pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (2023.6.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in d:\program files\python310\lib\site-packages (from pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (0.10.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\program files\python310\lib\site-packages (from rich>=11.0.0->pytorch_tabular[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\program files\python310\lib\site-packages (from rich>=11.0.0->pytorch_tabular[extra]) (2.15.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\program files\python310\lib\site-packages (from scikit-learn>=1.3.0->pytorch_tabular[extra]) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\program files\python310\lib\site-packages (from scikit-learn>=1.3.0->pytorch_tabular[extra]) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\program files\python310\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (3.4.3)
# Requirement already satisfied: grpcio>=1.48.2 in d:\program files\python310\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.56.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\program files\python310\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.22.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\program files\python310\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.7.1)
# Requirement already satisfied: setuptools>=41.0.0 in d:\program files\python310\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (69.0.3)
# Requirement already satisfied: wheel>=0.26 in d:\program files\python310\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.42.0)
# Requirement already satisfied: absl-py>=0.4 in d:\program files\python310\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\program files\python310\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\program files\python310\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.3.6)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in d:\program files\python310\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.0.0)
# Requirement already satisfied: networkx in d:\program files\python310\lib\site-packages (from torch>=1.11.0->pytorch_tabular[extra]) (3.0)
# Requirement already satisfied: jinja2 in d:\program files\python310\lib\site-packages (from torch>=1.11.0->pytorch_tabular[extra]) (3.1.2)
# Requirement already satisfied: sympy in d:\program files\python310\lib\site-packages (from torch>=1.11.0->pytorch_tabular[extra]) (1.11.1)
# Requirement already satisfied: filelock in d:\program files\python310\lib\site-packages (from torch>=1.11.0->pytorch_tabular[extra]) (3.9.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in d:\program files\python310\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (3.1.42)
# Requirement already satisfied: appdirs>=1.4.3 in d:\program files\python310\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (1.4.4)
# Requirement already satisfied: setproctitle in d:\program files\python310\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (1.3.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in d:\program files\python310\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (0.4.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in d:\program files\python310\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (1.41.0)
# Requirement already satisfied: psutil>=5.0.0 in d:\program files\python310\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (5.9.5)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in d:\program files\python310\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (8.1.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in d:\program files\python310\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (3.0.10)
# Requirement already satisfied: comm>=0.1.3 in d:\program files\python310\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (0.1.3)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in d:\program files\python310\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (4.0.10)
# Requirement already satisfied: traitlets>=4.3.1 in d:\program files\python310\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (5.9.0)
# Requirement already satisfied: ipython>=6.1.0 in d:\program files\python310\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (8.13.2)
# Requirement already satisfied: colorama in d:\program files\python310\lib\site-packages (from Click!=8.0.0,>=7.1->wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in d:\program files\python310\lib\site-packages (from docker-pycreds>=0.4.0->wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (1.16.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\program files\python310\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (3.8.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\program files\python310\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (4.0.11)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\program files\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (4.9)
# Requirement already satisfied: urllib3<2.0 in d:\program files\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.26.13)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\program files\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\program files\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\program files\python310\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.3.1)
# Requirement already satisfied: matplotlib-inline in d:\program files\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.1.6)
# Requirement already satisfied: decorator in d:\program files\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (5.1.1)
# Requirement already satisfied: stack-data in d:\program files\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.6.2)
# Requirement already satisfied: pickleshare in d:\program files\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in d:\program files\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (3.0.38)
# Requirement already satisfied: jedi>=0.16 in d:\program files\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.18.2)
# Requirement already satisfied: backcall in d:\program files\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.2.0)
# Requirement already satisfied: mdurl~=0.1 in d:\program files\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.0.0->pytorch_tabular[extra]) (0.1.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\program files\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\program files\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\program files\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\program files\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in d:\program files\python310\lib\site-packages (from sympy->torch>=1.11.0->pytorch_tabular[extra]) (1.2.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\program files\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\program files\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\program files\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\program files\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\program files\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\program files\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (6.0.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\program files\python310\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\program files\python310\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.8.3)
# Requirement already satisfied: wcwidth in d:\program files\python310\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.2.6)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in d:\program files\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\program files\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (3.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in d:\program files\python310\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (2.2.1)
# Requirement already satisfied: pure-eval in d:\program files\python310\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in d:\program files\python310\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->pytorch_tabular[extra]) (1.2.0)
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: D:\Program Files\Python310\python.exe -m pip install --upgrade pip

# %%
SEED = 42

import os

import random
random.seed(SEED)

import numpy as np
np.random.seed(SEED)

import pandas as pd

from pytorch_tabular import TabularModel
from pytorch_tabular.models import CategoryEmbeddingModelConfig
from pytorch_tabular.config import (
    DataConfig,
    OptimizerConfig,
    TrainerConfig,
)

# %% [markdown]
# 1.Divide the dataset (‘hdb_price_prediction.csv’) into train, validation and test sets by using entries from year 2019 and before as training data, year 2020 as validation data and year 2021 as test data.
# **Do not** use data from year 2022 and year 2023.

# %%
df = pd.read_csv('hdb_price_prediction.csv')

# YOUR CODE HERE
train_data = df[df['year'] <= 2019]
val_data = df[df['year'] == 2020]
test_data = df[df['year'] == 2021]

# %% [markdown]
# 2.Refer to the documentation of **PyTorch Tabular** and perform the following tasks: https://pytorch-tabular.readthedocs.io/en/latest/#usage
# - Use **[DataConfig](https://pytorch-tabular.readthedocs.io/en/latest/data/)** to define the target variable, as well as the names of the continuous and categorical variables.
# - Use **[TrainerConfig](https://pytorch-tabular.readthedocs.io/en/latest/training/)** to automatically tune the learning rate. Set batch_size to be 1024 and set max_epoch as 50.
# - Use **[CategoryEmbeddingModelConfig](https://pytorch-tabular.readthedocs.io/en/latest/models/#category-embedding-model)** to create a feedforward neural network with 1 hidden layer containing 50 neurons.
# - Use **[OptimizerConfig](https://pytorch-tabular.readthedocs.io/en/latest/optimizer/)** to choose Adam optimiser. There is no need to set the learning rate (since it will be tuned automatically) nor scheduler.
# - Use **[TabularModel](https://pytorch-tabular.readthedocs.io/en/latest/tabular_model/)** to initialise the model and put all the configs together.

# %%
# YOUR CODE HERE
# define data
data_config = DataConfig(
    target=['resale_price'],
    continuous_cols=['dist_to_nearest_stn', 'dist_to_dhoby', 'degree_centrality', 'eigenvector_centrality', 'remaining_lease_years', 'floor_area_sqm'],
    categorical_cols=['month', 'town', 'flat_model_type', 'storey_range']
)

# define trainer
trainer_config = TrainerConfig(
    batch_size=1024,
    max_epochs=50,
    auto_lr_find=True  # to find an optimal lr
)

# define model
model_config = CategoryEmbeddingModelConfig(
    task='regression',
    layers='50'
)

# define optimizer
optimizer_config = OptimizerConfig(
    optimizer='Adam'
)

# initialization
model = TabularModel(
    data_config=data_config,
    model_config=model_config,
    optimizer_config=optimizer_config,
    trainer_config=trainer_config,
)

# train the model
model.fit(train=train_data, validation=val_data, seed=SEED)

# test the model
res = model.evaluate(test_data)
pred = model.predict(test_data)
# Out:
# 2024-03-13 00:50:29,257 - {pytorch_tabular.tabular_model:140} - INFO - Experiment Tracking is turned off
# Seed set to 42
# 2024-03-13 00:50:29,301 - {pytorch_tabular.tabular_model:524} - INFO - Preparing the DataLoaders
# 2024-03-13 00:50:29,328 - {pytorch_tabular.tabular_datamodule:499} - INFO - Setting up the datamodule for
# regression task
# 2024-03-13 00:50:29,463 - {pytorch_tabular.tabular_model:574} - INFO - Preparing the Model: CategoryEmbeddingModel
# 2024-03-13 00:50:29,524 - {pytorch_tabular.tabular_model:340} - INFO - Preparing the Trainer
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# 2024-03-13 00:50:30,611 - {pytorch_tabular.tabular_model:630} - INFO - Auto LR Find Started
# You are using a CUDA device ('NVIDIA GeForce RTX 4060 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# D:\Program Files\Python310\lib\site-packages\pytorch_lightning\callbacks\model_checkpoint.py:639: Checkpoint directory E:\git\SC4001\Programming Assignment\saved_models exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# D:\Program Files\Python310\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# D:\Program Files\Python310\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Finding best initial lr:   0%|          | 0/100 [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_steps=100` reached.
# Learning rate set to 0.5754399373371567
# Restoring states from the checkpoint path at E:\git\SC4001\Programming Assignment\.lr_find_48de1857-b168-4245-a9e5-0db302ad89ec.ckpt
# Restored all states from the checkpoint at E:\git\SC4001\Programming Assignment\.lr_find_48de1857-b168-4245-a9e5-0db302ad89ec.ckpt
# 2024-03-13 00:50:48,811 - {pytorch_tabular.tabular_model:643} - INFO - Suggested LR: 0.5754399373371567. For plot
# and detailed analysis, use `find_learning_rate` method.
# 2024-03-13 00:50:48,827 - {pytorch_tabular.tabular_model:652} - INFO - Training Started
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃   ┃ Name             ┃ Type                      ┃ Params ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ 0 │ _backbone        │ CategoryEmbeddingBackbone │  2.9 K │
# │ 1 │ _embedding_layer │ Embedding1dLayer          │  1.5 K │
# │ 2 │ head             │ LinearHead                │     51 │
# │ 3 │ loss             │ MSELoss                   │      0 │
# └───┴──────────────────┴───────────────────────────┴────────┘
# Trainable params: 4.5 K
# Non-trainable params: 0
# Total params: 4.5 K
# Total estimated model params size (MB): 0
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2024-03-13 00:51:07,587 - {pytorch_tabular.tabular_model:663} - INFO - Training the model completed
# 2024-03-13 00:51:07,590 - {pytorch_tabular.tabular_model:1489} - INFO - Loading the best model
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Output()
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │       6465972736.0        │
# │  test_mean_squared_error  │       6465972736.0        │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# 3.Report the test RMSE error and the test R2 value that you obtained.

# %%
# YOUR CODE & RESULT HERE
from sklearn.metrics import r2_score

# report RMSE and R2
RMSE = np.sqrt(res[0]['test_mean_squared_error'])
r2 = r2_score(test_data['resale_price'], pred['resale_price_prediction'])

print(f"RMSE: {RMSE}")
print(f"R2: {r2}")
# Out:
# RMSE: 80411.27244360706
# R2: 0.7555578327813541

# %% [markdown]
# 4.Print out the corresponding rows in the dataframe for the top 25 test samples with the largest errors. Identify a trend in these poor predictions and suggest a way to reduce these errors.

# %%
# YOUR CODE & RESULT HERE
# we use squared difference to be the error here
test_data['resale_price_prediction'] = pred['resale_price_prediction']
test_data['error'] = (test_data['resale_price'] - test_data['resale_price_prediction']) ** 2
sorted = test_data.sort_values(by='error', ascending=False)
top_25 = sorted.head(25)
top_25
# Out:
# C:\Users\Chihao Shen\AppData\Local\Temp\ipykernel_30860\1095613762.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['resale_price_prediction'] = pred['resale_price_prediction']
# C:\Users\Chihao Shen\AppData\Local\Temp\ipykernel_30860\1095613762.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['error'] = (test_data['resale_price'] - test_data['resale_price_prediction']) ** 2
#         month  year         town                full_address   nearest_stn
# 92405      11  2021  BUKIT MERAH            46 SENG POH ROAD   Tiong Bahru  \
# 105372      2  2021   QUEENSTOWN            46 STIRLING ROAD  Commonwealth
# 106192     12  2021   QUEENSTOWN              89 DAWSON ROAD    Queenstown
# 105869      8  2021   QUEENSTOWN            42 STIRLING ROAD    Queenstown
# 106057     10  2021   QUEENSTOWN              92 DAWSON ROAD    Queenstown
# 105695      6  2021   QUEENSTOWN              91 DAWSON ROAD    Queenstown
# 105696      6  2021   QUEENSTOWN              89 DAWSON ROAD    Queenstown
# 92442      11  2021  BUKIT MERAH          127D KIM TIAN ROAD   Tiong Bahru
# 105702      6  2021   QUEENSTOWN         150 MEI LING STREET    Queenstown
# 105699      6  2021   QUEENSTOWN              91 DAWSON ROAD    Queenstown
# 105468      3  2021   QUEENSTOWN              90 DAWSON ROAD    Queenstown
# 92340      10  2021  BUKIT MERAH            56 HAVELOCK ROAD   Tiong Bahru
# 90957       6  2021  BUKIT BATOK  288A BUKIT BATOK STREET 25   Bukit Batok
# 88081       8  2021   ANG MO KIO    310A ANG MO KIO AVENUE 1    Ang Mo Kio
# 106190     12  2021   QUEENSTOWN              92 DAWSON ROAD    Queenstown
# 105961      9  2021   QUEENSTOWN              90 DAWSON ROAD    Queenstown
# 92226       9  2021  BUKIT MERAH          96A HENDERSON ROAD   Tiong Bahru
# 112128     12  2021     TAMPINES      156 TAMPINES STREET 12      Tampines
# 114389     10  2021    WOODLANDS     805 WOODLANDS STREET 81     Woodlands
# 105966      9  2021   QUEENSTOWN              91 DAWSON ROAD    Queenstown
# 106191     12  2021   QUEENSTOWN              89 DAWSON ROAD    Queenstown
# 92504      12  2021  BUKIT MERAH            49 KIM PONG ROAD   Tiong Bahru
# 105526      4  2021   QUEENSTOWN              92 DAWSON ROAD    Queenstown
# 105523      4  2021   QUEENSTOWN              91 DAWSON ROAD    Queenstown
# 105792      7  2021   QUEENSTOWN              91 DAWSON ROAD    Queenstown
#
#         dist_to_nearest_stn  dist_to_dhoby  degree_centrality
# 92405              0.581977       2.309477           0.016807  \
# 105372             0.570988       4.922054           0.016807
# 106192             0.658035       3.807573           0.016807
# 105869             0.554599       4.841933           0.016807
# 106057             0.584731       3.882019           0.016807
# 105695             0.745596       3.720593           0.016807
# 105696             0.658035       3.807573           0.016807
# 92442              0.686789       2.664024           0.016807
# 105702             0.245207       4.709043           0.016807
# 105699             0.745596       3.720593           0.016807
# 105468             0.701852       3.763948           0.016807
# 92340              0.451387       2.128424           0.016807
# 90957              1.292540      10.763777           0.016807
# 88081              0.860056       7.263401           0.016807
# 106190             0.584731       3.882019           0.016807
# 105961             0.701852       3.763948           0.016807
# 92226              0.586629       2.932814           0.016807
# 112128             0.370873      12.479752           0.033613
# 114389             0.419275      16.945885           0.016807
# 105966             0.745596       3.720593           0.016807
# 106191             0.658035       3.807573           0.016807
# 92504              0.468378       2.365532           0.016807
# 105526             0.584731       3.882019           0.016807
# 105523             0.745596       3.720593           0.016807
# 105792             0.745596       3.720593           0.016807
#
#         eigenvector_centrality                 flat_model_type
# 92405                 0.047782                3 ROOM, Standard  \
# 105372                0.005350                 4 ROOM, Terrace
# 106192                0.008342  4 ROOM, Premium Apartment Loft
# 105869                0.008342                 4 ROOM, Terrace
# 106057                0.008342  4 ROOM, Premium Apartment Loft
# 105695                0.008342  4 ROOM, Premium Apartment Loft
# 105696                0.008342  4 ROOM, Premium Apartment Loft
# 92442                 0.047782                5 ROOM, Improved
# 105702                0.008342            EXECUTIVE, Apartment
# 105699                0.008342  4 ROOM, Premium Apartment Loft
# 105468                0.008342  4 ROOM, Premium Apartment Loft
# 92340                 0.047782                5 ROOM, Improved
# 90957                 0.000217            EXECUTIVE, Apartment
# 88081                 0.006243                5 ROOM, Improved
# 106190                0.008342  4 ROOM, Premium Apartment Loft
# 105961                0.008342  4 ROOM, Premium Apartment Loft
# 92226                 0.047782                5 ROOM, Improved
# 112128                0.000229           EXECUTIVE, Maisonette
# 114389                0.000024            EXECUTIVE, Apartment
# 105966                0.008342  4 ROOM, Premium Apartment Loft
# 106191                0.008342  4 ROOM, Premium Apartment Loft
# 92504                 0.047782                3 ROOM, Standard
# 105526                0.008342  4 ROOM, Premium Apartment Loft
# 105523                0.008342  4 ROOM, Premium Apartment Loft
# 105792                0.008342  4 ROOM, Premium Apartment Loft
#
#         remaining_lease_years  floor_area_sqm storey_range  resale_price
# 92405               50.166667            88.0     01 TO 03      780000.0  \
# 105372              46.916667           134.0     01 TO 03      975000.0
# 106192              93.333333           109.0     04 TO 06      968000.0
# 105869              46.416667           120.0     01 TO 03      930000.0
# 106057              93.500000            97.0     13 TO 15      958000.0
# 105695              93.916667            97.0     07 TO 09      930000.0
# 105696              93.916667           109.0     10 TO 12      950000.0
# 92442               90.333333           113.0     16 TO 18     1165000.0
# 105702              73.416667           148.0     10 TO 12     1235000.0
# 105699              93.916667           109.0     31 TO 33     1032888.0
# 105468              94.166667            95.0     10 TO 12      920000.0
# 92340               90.750000           114.0     34 TO 36     1245000.0
# 90957               75.583333           144.0     10 TO 12      968000.0
# 88081               90.166667           121.0     28 TO 30     1100000.0
# 106190              93.333333            97.0     16 TO 18      938888.0
# 105961              93.583333            97.0     10 TO 12      900000.0
# 92226               96.750000           113.0     28 TO 30     1220000.0
# 112128              61.750000           148.0     01 TO 03      998000.0
# 114389              71.250000           189.0     04 TO 06      980000.0
# 105966              93.666667            97.0     25 TO 27      968800.0
# 106191              93.416667            97.0     19 TO 21      950000.0
# 92504               50.166667            88.0     01 TO 03      695000.0
# 105526              94.083333            97.0     16 TO 18      928000.0
# 105523              94.083333            97.0     07 TO 09      878000.0
# 105792              93.833333            97.0     34 TO 36      988000.0
#
#         resale_price_prediction         error
# 92405               360914.6250  1.756326e+11
# 105372              561211.6875  1.712208e+11
# 106192              560444.8750  1.661012e+11
# 105869              535871.5625  1.553372e+11
# 106057              574577.0000  1.470132e+11
# 105695              549269.4375  1.449558e+11
# 105696              583298.4375  1.344700e+11
# 92442               799521.9375  1.335742e+11
# 105702              869783.4375  1.333831e+11
# 105699              670265.9375  1.314948e+11
# 105468              558144.5625  1.309394e+11
# 92340               891536.7500  1.249363e+11
# 90957               618831.4375  1.219187e+11
# 88081               752132.8125  1.210116e+11
# 106190              596071.0625  1.175235e+11
# 105961              559080.9375  1.162258e+11
# 92226               881814.3125  1.143696e+11
# 112128              666968.3125  1.095820e+11
# 114389              650036.5625  1.088759e+11
# 105966              638866.5625  1.088561e+11
# 106191              620261.0625  1.087278e+11
# 92504               365288.8125  1.087095e+11
# 105526              598382.1875  1.086479e+11
# 105523              550246.9375  1.074221e+11
# 105792              660857.6250  1.070221e+11

# %% [markdown]
# We can observe from the above dataframe and the plots below that these flats have some similar features. For instances, most flats have its model to be 4 ROOM, Premium Apartment Loft; most flats are close to Queenstown; most flats have shorter distances to the nearest MRT station and Dhoby Ghaut MRT station. These indicates that these flats have relatively higher resale price. We can also observe this from the scatter plots and data below, where the resale price has a correlation of 0.45 with the error. Therefore, the flats that has relatively higher resale price tend have trends to be predicted poorly by the model.
#
# Additionally, from the first line plot below, we can figure out that the predicted prices seem to have trends to be lower than the actual resale prices.
#
# To reduce these errors, we can
#
# 1. Refine data sampling such that the data should be distributed equally within both high-priced and ordinary properties. It is possible that the data are mostly concentrate on properties having ordinary values, which may cause the models to be biased, resulting in model performing not well on those data with properties having high-priced values.
#
# 2. We can add interaction terms to the model. Since some terms may highly correlated to each other, for example, flats have premium settings tend to near MRT stations and have a relatively higher resale price, therefore, adding interaction terms may increase the performance of the model.
#
# 3. Enhance model robustness by increasing the number of hidden layers, number of neurons in each layer, and adjusting the training configurations such as type of optimizer, number of max epoch and batch size.
#
# 4. Adding additional regularization terms such as using L1 or L2 norms to prevent the model from overfitting problem in order to help the model perform better on generalized data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

x = range(1, 26)

# plot the difference between actual and predicted values
plt.plot(x, top_25['resale_price'], label='Actual Resale Price')
plt.plot(x, top_25['resale_price_prediction'], label='Predicted Resale Price')
plt.xlabel('top 25 error index')
plt.ylabel('resale price')
plt.xticks(x)
plt.legend()
plt.title("Actual Price v.s. Predictions of top 25 results")
plt.show()

# %%
# plot the distribution and trend for categorical features
categorical_features = ['month', 'town', 'flat_model_type', 'storey_range', 'nearest_stn']

fig, axes = plt.subplots(5, 1, figsize=(30, 100))
axes = axes.flatten()

for i, feature in enumerate(categorical_features):
    sns.boxplot(data=test_data, x=feature, y='error', ax=axes[i])
    axes[i].set_title(f'Error Distribution for {feature.capitalize()}')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('error')
    axes[i].tick_params(axis='x', rotation=60)

plt.show()

# %%
# plot the distribution and trend for continuous features
continuous_features = [
    'dist_to_nearest_stn', 'dist_to_dhoby', 'degree_centrality', 
    'eigenvector_centrality', 'remaining_lease_years', 'floor_area_sqm',
    'resale_price'
]

plt.figure(figsize=(20, 20))

# create scatter plots
for i, feature in enumerate(continuous_features, 1):
    plt.subplot(3, 3, i)
    sns.scatterplot(data=test_data, x=feature, y='error', alpha=0.6)
    plt.title(f'Error w.r.t. {feature.capitalize()}')

plt.tight_layout()
plt.show()

# %%
# calculate the correlation
selected_features = continuous_features + ['error']
correlation_matrix = test_data[selected_features].corr()
error_correlations = correlation_matrix['error'].drop('error')
error_correlations
# Out:
# dist_to_nearest_stn       0.019910
# dist_to_dhoby            -0.029786
# degree_centrality        -0.023117
# eigenvector_centrality    0.038742
# remaining_lease_years     0.115610
# floor_area_sqm            0.190438
# resale_price              0.451428
# Name: error, dtype: float64

# %%
model.save_model("b1")
